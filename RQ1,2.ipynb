# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
# !pip install wordcloud
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.3/168.3 kB 725.4 kB/s eta 0:00:00a 0:00:01
# ...

# %%
# Plotting the box plot for user satisfaction scores
plt.figure(figsize=(8, 5))
plt.boxplot(df_user_satisfaction['Satisfaction_Score'], vert=False, patch_artist=True)
plt.title('Distribution of User Satisfaction Scores')
plt.xlabel('Satisfaction Score')
plt.grid(True)
plt.show()

# %%
# Generating a word cloud for user feedback
feedback_text = ' '.join(df_feedback['Feedback'])
wordcloud = WordCloud(width=800, height=400, background_color ='white').generate(feedback_text)

# Display the generated image:
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of User Feedback on LLMs')
plt.show()
